# %% [markdown]
# ## **Data Quality**
#  - Duplicate Records:
#    Identify and quantify duplicate entries (e.g., based on FORMATTED_ADDRESS).
#  - Inconsistent or Invalid Data:
#    Check for unusual values in BEDS, BATH (e.g., negative values, unrealistic ranges).
#  - Validate geospatial coordinates (LATITUDE, LONGITUDE) for out-of-bound values.
#  - Data Completeness:
#    Assess completeness of address-related fields (ADDRESS, LOCALITY, etc.).

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np

# %%
house_data = pd.read_csv("C:/Users/1999i/Documents/data mange/Lab Lectures/Project/Data/NY-House-Dataset.csv")
q = house_data.shape
print(f"Original data shape {q}")
# Extract the names before the comma
house_data['State_City'] = house_data['STATE'].str.extract(r'^([\w\s]+),')
# Extracting new york county regions
NY_county = house_data[house_data['State_City'].isin(['New York', 'Manhattan', 'Roosevelt Island', 'New York City'])]
qq = NY_county.shape
print(f"Properties located only in New York County data shape {qq}")
# Out:
# Original data shape (4801, 17)
# Properties located only in New York County data shape (1295, 18)

# %%
NY_county = NY_county[['BROKERTITLE', 'TYPE', 'PRICE', 'BEDS','BATH','PROPERTYSQFT','MAIN_ADDRESS','STATE', 'State_City','LATITUDE','LONGITUDE']]
NY_county.head(3)
# Out:
#                                    BROKERTITLE            TYPE      PRICE  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale     315000
# 1                          Brokered by Serhant  Condo for sale  195000000
# 3                          Brokered by COMPASS  Condo for sale      69000
#
#    BEDS  BATH  PROPERTYSQFT  \
# 0     2   2.0        1400.0
# 1     7  10.0       17545.0
# 3     3   1.0         445.0
#
#                                         MAIN_ADDRESS                STATE  \
# 0             2 E 55th St Unit 803New York, NY 10022   New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...   New York, NY 10019
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022  Manhattan, NY 10022
#
#   State_City   LATITUDE  LONGITUDE
# 0   New York  40.761255 -73.974483
# 1   New York  40.766393 -73.980991
# 3  Manhattan  40.761398 -73.974613

# %%
duplicates = NY_county[NY_county.duplicated(subset=['BROKERTITLE', 'MAIN_ADDRESS'])]
w = duplicates.shape
print(f"Duplicate rows shape: {w}")
NY_county_cleaned = NY_county.drop_duplicates(subset=['BROKERTITLE', 'MAIN_ADDRESS'])
ww = NY_county_cleaned.shape
print(f"After removing Duplicate rows shape: {ww}")
# Out:
# Duplicate rows shape: (64, 11)
# After removing Duplicate rows shape: (1231, 11)

# %%
# Validate geospatial coordinates (LATITUDE, LONGITUDE) for out-of-bound values.
# New York City bounds
nyc_bounds = {
    'lat_min': 40.4774,
    'lat_max': 40.9176,
    'lon_min': -74.2591,
    'lon_max': -73.7002
}

# Filter data valid coords
dt_county = NY_county_cleaned[
    (NY_county_cleaned['LATITUDE'] >= nyc_bounds['lat_min']) &
    (NY_county_cleaned['LATITUDE'] <= nyc_bounds['lat_max']) &
    (NY_county_cleaned['LONGITUDE'] >= nyc_bounds['lon_min']) &
    (NY_county_cleaned['LONGITUDE'] <= nyc_bounds['lon_max'])
]

e = dt_county.shape
print(f"Valid coordinates shape: {e}")

invalid_coords = NY_county_cleaned[~NY_county_cleaned.index.isin(dt_county.index)]
ee = invalid_coords.shape
print(f"Invalid coordinates shape: {ee}")
# Out:
# Valid coordinates shape: (1231, 11)
# Invalid coordinates shape: (0, 11)

# %%
dt_county.TYPE.unique()
# Out:
# array(['Condo for sale', 'Townhouse for sale', 'Co-op for sale',
#        'For sale', 'House for sale', 'Pending', 'Foreclosure',
#        'Multi-family home for sale', 'Land for sale', 'Condop for sale',
#        'Contingent'], dtype=object)

# %%
dt_county.BROKERTITLE.unique()
# Out:
# array(['Brokered by Douglas Elliman  -111 Fifth Ave',
#        'Brokered by Serhant', 'Brokered by COMPASS',
#        "Brokered by Sotheby's International Realty - East Side Manhattan Brokerage",
#        'Brokered by Douglas Elliman - 575 Madison Ave',
#        'Brokered by Corcoran Chelsea/Flatiron',
#        'Brokered by Brown Harris Stevens',
#        'Brokered by Brown Harris Stevens - 445 Park Avenue',
#        'Brokered by Brown Harris Stevens - 1926 Broadway',
#        'Brokered by Engel & Volkers Brownstone Brooklyn',
#        'Built by Toll Brothers', 'Brokered by Avenues - Headquarters',
#        'Brokered by Corcoran East Side', 'Brokered by Exp Realty',
#        'Brokered by Island Advantage Rlty, Llc',
#        'Brokered by Garfield, Leslie J. & Co., Inc.',
#        'Brokered by Corcoran West Side',
#        'Brokered by All American Realty Management',
#        'Brokered by Byson Real Estate Company - Byson Real Estate Company',
#        "Brokered by CHRISTIE'S INT.REAL ESTATE GROUP",
#        'Brokered by Corcoran Park Avenue South',
#        'Brokered by AI Realty Brokerage LLC',
#        "Brokered by Sotheby's International Realty - Downtown Manhattan",
#        'Brokered by Oxford Property Group',
#        'Brokered by Corcoran West Side Gallery',
#        'Brokered by HOULIHAN LAWRENCE - LaGrangeville',
#        'Brokered by Signature Premier Properties',
#        'Brokered by Keller Williams NYC',
#        'Brokered by CLAS - Classic Marketing, LLC',
#        'Brokered by ANNE LOPA REAL ESTATE',
#        'Brokered by Living NY - Main Office',
#        'Brokered by Nest Seekers International, Westside',
#        'Brokered by Steven Corcoran Real Estate LLC - Steven Corcoran Real Estate TudorCity.com',
#        'Brokered by Douglas Elliman - 3544 Johnson Ave',
#        'Brokered by Nest Seekers International, Internationa',
#        'Brokered by Extell Marketing Group LLC',
#        'Brokered by Peter Ashe Real Estate- Peter Ashe Real Estate',
#        'Brokered by Douglas Elliman - 1995 Broadway',
#        'Brokered by Corcoran SoHo',
#        'Brokered by Brooklyn Bound Realty Corp',
#        'Brokered by Spire Group Inc.- Main Office',
#        'Brokered by The Agency',
#        'Brokered by OneKey MLS LLC - Realmart Realty, LLC',
#        'Brokered by LoHo Realty Inc',
#        "Brokered by Sotheby's International Realty, Inc.",
#        'Brokered by Adcny Realty Corp',
#        'Brokered by BHHS New York Properties',
#        'Brokered by Corcoran Westside Columbus', 'Brokered by Corcoran',
#        'Brokered by Nest Seekers International, Midtown',
#        'Brokered by City Connections Realty',
#        'Brokered by Coldwell Banker Reliable Real Estate',
#        'Brokered by New Heights Realty',
#        'Brokered by Harlem Lofts Inc.- Harlem Lofts, Inc.',
#        'Brokered by Elegran Real Estate And Development',
#        'Brokered by Keller Williams Realty Group',
#        'Brokered by Myc & Associates Inc',
#        'Brokered by BRAI - Braithwaite Realty LLC',
#        'Brokered by Harbor Properties International LLC',
#        'Brokered by Hudson Group Realty Network Inc', 'Brokered by Ubiq',
#        'Brokered by Coldwell Banker Warburg', 'Brokered by RE MAX Edge',
#        'Brokered by Yoreevo',
#        'Brokered by Bond New York- Columbus Circle',
#        'Brokered by Corcoran Park Slope',
#        'Brokered by Douglas Elliman - 140 Franklin',
#        'Brokered by ETPG - Eastpointe Properties Group',
#        'Brokered by Coldwell Banker M&D Good Life',
#        'Brokered by Mcgrath Realty Inc.',
#        'Brokered by TUDO - Tudor Realty Services',
#        'Brokered by Brown Harris Stevens - 43 North Moore Street',
#        'Brokered by Dynamik Real Estate',
#        'Brokered by Vandenberg -The Townhouse Experts',
#        'Brokered by Douglas Elliman - New Development',
#        'Brokered by SBRW - SBROWNRE,LLC',
#        'Brokered by Brown Harris Stevens- 3531 Johnson Avenue',
#        'Brokered by Nestapple', 'Brokered by Redfin Real Estate',
#        'Brokered by Geo Real Estate Group Inc', 'Brokered by Level',
#        'Brokered by Gerard R Desgranges',
#        'Brokered by Nest Seekers International, Tribeca',
#        'Brokered by Grandeur Realty, Inc.',
#        'Brokered by TDMT - The Development Marketing Team',
#        'Brokered by Corcoran Bedford Stuyvesant',
#        'Brokered by Corcoran Williamsburg Bedford',
#        'Brokered by New York Residence',
#        'Brokered by Douglas Elliman - 690 Washington',
#        'Brokered by Hauseit LLC - Hauseit LLC',
#        'Brokered by Manhattan Network Inc', 'Brokered by Epic Homes NY',
#        'Brokered by Highline Residential - Highline Residential',
#        'NoBroker', 'Brokered by Mirador Real Estate LLC',
#        'Brokered by Keller Williams NYC - New York Living Solutions',
#        'Brokered by Douglas Elliman - Rental Center',
#        'Brokered by Modlin Group LLC', 'Brokered by R New York',
#        'Brokered by Corcoran Brooklyn Heights',
#        'Brokered by Douglas Elliman - 936 Broadway',
#        'Brokered by Coldwell Banker Reliable',
#        'Brokered by Douglas Elliman - 2112 Frederick Douglass Blvd',
#        'Brokered by Brown Harris Stevens - 130 Fifth Avenue',
#        'Brokered by Realmart Realty, LLC', 'Brokered by Real Broker Llc',
#        'Brokered by IZSA - Miriam Izsak Realty LLC',
#        'Brokered by Foxworth Realty, Inc.',
#        'Brokered by Nest Seekers International, Southampton',
#        'Brokered by William Raveis Real Estate - Rye',
#        'Brokered by BERGEN BASIN REALTY',
#        'Brokered by REAL NEW YORK - Remote Brooklyn',
#        'Brokered by NEXT - NextStopNY',
#        'Brokered by EXIT REALTY TOP PROPERTIES',
#        'Brokered by DIGS - Digs Realty Group EMAIL)',
#        'Brokered by Keller Williams Realty NYC Grp',
#        'Brokered by Listwithfreedom.Com, Inc.', 'Brokered by Reserve',
#        'Brokered by Keller Williams Legendary',
#        'Brokered by Listed New York Elite Inc',
#        'Brokered by ANNE - Anne Weintraub', 'Brokered by eXp Realty NYC',
#        'Brokered by Brown Harris Stevens - 129 Montague Street',
#        'Brokered by REALHome Services & Solutions',
#        'Brokered by Homedax Real Estate Llc',
#        'Brokered by William Raveis New York City',
#        'Brokered by One Manhattan real estate - Upper East Side office',
#        'Brokered by Broadway Realty',
#        'Brokered by The Greene Realty Group',
#        'Brokered by ALTA Real Estate', 'Brokered by Link Ny Realty',
#        'Brokered by E Realty International Corp',
#        'Brokered by Prime Ny Inc.',
#        'Brokered by H P Greenfield Real Estate Ltd',
#        'Brokered by E House Realty & Mgt. Inc.',
#        'Brokered by ANNF - Ann Ferguson LLC', 'Brokered by VYLLA HOME',
#        'Brokered by CORE Group Marketing, LLC',
#        'Brokered by Sloane Square LLC',
#        'Brokered by KELLER WILLIAMS REALTY LANDMARK II',
#        'Brokered by Brown Harris Stevens - 100 Seventh Avenue',
#        'Brokered by Fillmore Real Estate Fusion Team, INC.',
#        'Brokered by Yoreevo Llc',
#        'Brokered by ACCS - Access Property Group',
#        'Brokered by REAL NEW YORK - Chelsea',
#        'Brokered by Howard Hanna | Rand Realty',
#        'Brokered by BMB Living, Inc.', 'Brokered by OFFICIAL',
#        'Brokered by Weichert Properties', 'Brokered by TURFNYC LLC',
#        'Brokered by Ll Real Estate Services, Llc',
#        'Brokered by Industrie Residential',
#        'Brokered by Nest Seekers International, Long Island',
#        'Brokered by Martini Real Estate - Martini Real Estate',
#        'Brokered by Engel & V�������',
#        'Brokered by Leven Real Estate - Head Office',
#        'Brokered by UbiQ NY Ltd',
#        'Brokered by Dolly Lenz Real Estate LLC',
#        'Brokered by The Bouklis Group - The Bouklis Group',
#        'Brokered by Anita Loewy',
#        'Brokered by CARINI GROUP - CARINI GROUP',
#        'Brokered by Michael A. Kaufman, Licensed Real Estate Broker',
#        'Brokered by Silversons Realty, LLC', 'Brokered by Deutsch Realty',
#        'Brokered by Toll Brothers, Inc',
#        'Brokered by Nardoni Realty Inc.',
#        'Brokered by REAL NEW YORK - Lower East Side',
#        'Brokered by Corcoran Legends Realty',
#        'Brokered by Corcoran Fort Greene',
#        'Brokered by FOXR - Fox Residential Group',
#        'Brokered by Wilk Real Estate I Llc',
#        'Brokered by Douglas Elliman - 280 Metropolitan',
#        'Brokered by OneKey MLS LLC - Foxworth Realty, Inc.',
#        'Brokered by BH Realty Group - Manhattan - Headquarters',
#        'Brokered by J Shayovitz Real Estate Corp'], dtype=object)

# %% [markdown]
# ## **Data Profiling**
# - Missing values
# - filtering whole numbers for beds and bath
# - variable overview : summary statistics
# - Data Distribution Analysis: Histograms: Plot histograms for numerical variables (PRICE, BEDS, BATH, scores) to visualize their distributions.
# - Pie Charts: Proportions of house types (TYPE) or distribution of states (STATE).
# - Spatial Analysis: Heatmap: Use heatmap overlays to show density of houses or amenities.

# %%
print(f"Missing data in New York County:")
dt_county.isna().sum()
# Out:
# Missing data in New York County:
# BROKERTITLE     0
# TYPE            0
# PRICE           0
# BEDS            0
# BATH            0
# PROPERTYSQFT    0
# MAIN_ADDRESS    0
# STATE           0
# State_City      0
# LATITUDE        0
# LONGITUDE       0
# dtype: int64

# %%
# variable overview : summary statistics
dt_county.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  1.231000e+03  1231.000000  1231.000000   1231.000000  1231.000000
# mean   6.029277e+06     2.968318     2.459236   2497.490908    40.766458
# std    6.173164e+07     2.260614     1.932233   2157.991161     0.033652
# min    2.494000e+03     1.000000     0.000000    230.000000    40.518484
# 25%    6.980000e+05     2.000000     1.000000   1431.000000    40.743561
# 50%    1.495000e+06     3.000000     2.000000   2184.207862    40.768047
# 75%    4.172500e+06     3.000000     3.000000   2184.207862    40.783670
# max    2.147484e+09    32.000000    20.000000  24000.000000    40.880930
#
#          LONGITUDE
# count  1231.000000
# mean    -73.973598
# std       0.022997
# min     -74.224418
# 25%     -73.987420
# 50%     -73.972208
# 75%     -73.958624
# max     -73.825917

# %%
# decimals in beds and baths
dt_county['beds_has_decimal'] = dt_county['BEDS'] % 1 != 0  # TRUE if ther is decimal
dt_county['bath_has_decimal'] = dt_county['BATH'] % 1 != 0  
beds_decimal_count = dt_county['beds_has_decimal'].sum()
bath_decimal_count = dt_county['bath_has_decimal'].sum()

print(f"Rows with decimal values in 'beds': {beds_decimal_count}")
print(f"Rows with decimal values in 'bath': {bath_decimal_count}")
# Out:
# Rows with decimal values in 'beds': 0
# Rows with decimal values in 'bath': 49

# %%
# filtering only whole numbers.
dt_county_ =  dt_county[dt_county['bath_has_decimal'] == False]
z = dt_county_.shape
print(f"Data shape filtering only whole numbers for beds and bath: {z}")
# Out:
# Data shape filtering only whole numbers for beds and bath: (1182, 13)

# %%
# variable overview : summary statistics
dt_county_.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  1.182000e+03  1182.000000  1182.000000   1182.000000  1182.000000
# mean   5.636089e+06     2.900169     2.462775   2357.622515    40.766465
# std    6.289851e+07     2.259278     1.971830   1864.468974     0.033680
# min    2.494000e+03     1.000000     0.000000    230.000000    40.518484
# 25%    6.792500e+05     2.000000     1.000000   1375.250000    40.743942
# 50%    1.412500e+06     3.000000     2.000000   2184.207862    40.767687
# 75%    3.898750e+06     3.000000     3.000000   2184.207862    40.783662
# max    2.147484e+09    32.000000    20.000000  24000.000000    40.880930
#
#          LONGITUDE
# count  1182.000000
# mean    -73.973607
# std       0.023013
# min     -74.224418
# 25%     -73.987286
# 50%     -73.972395
# 75%     -73.958623
# max     -73.825917

# %% [markdown]
# ## **Data Integration/ Data Enrichment**

# %%
walkscore = pd.read_csv("C:/Users/1999i/Documents/data mange/Lab Lectures/Project/Data/walkscore.csv")
q = walkscore.shape
print(f"walkscore data shape: {q}")
# Out:
# walkscore data shape: (93, 5)

# %%
walkscore.head(3)
# Out:
#                             Location  Bike Score  Transit Score  Walk Score  \
# 0      Midtown East, New York, 10022          82          100.0         100
# 1    Hell's Kitchen, New York, 10019          91          100.0          93
# 2  Upper East Side, Manhattan, 10065          83          100.0          99
#
#          Neighborhood
# 0  New York, NY 10022
# 1  New York, NY 10019
# 2  New York, NY 10065

# %%
walkscore.Location.unique()
# Out:
# array(['Midtown East, New York, 10022', "Hell's Kitchen, New York, 10019",
#        'Upper East Side, Manhattan, 10065', 'Manhattan, New York, 10027',
#        'West Village, New York, 10014', 'SoHo, New York, 10013',
#        'Two Bridges, Manhattan, 10002',
#        'Upper East Side, Manhattan, 10075', 'Manhattan, New York, 10128',
#        'SoHo, New York, 10012', 'Manhattan, New York, 10025',
#        'Manhattan, New York, 10023', 'East Harlem, New York, 10029',
#        'West Harlem, Manhattan, 10031',
#        'Upper East Side, Manhattan, 10021',
#        'Washington Heights, New York, 10032', 'Tribeca, New York, 10007',
#        'Upper West Side, Manhattan, 10024',
#        'Murray Hill, New York, 10016', "Hell's Kitchen, New York, 10036",
#        'Manhattan, New York, 10028', 'Midtown East, New York, 10017',
#        'New York, New York, 10033', 'Charleston, New York, 10309',
#        'Chelsea, New York, 10001', 'Greenwich Village, New York, 10003',
#        'New York, New York, 10069', 'Kingsbridge, New York, 10463',
#        'Manhattan, New York, 10009', 'Central Harlem, New York, 10030',
#        'Chelsea, New York, 10011', 'Central Harlem, New York, 10026',
#        'Inwood, New York', 'Manhattan, New York, 10004',
#        'Financial District, New York, 10004',
#        'Randalls-Wards Island, New York, 10035',
#        'Roosevelt Island, New York, 10044',
#        'Central Harlem, New York, 10037',
#        'Garment District, New York, 10018', 'Manhattan, New York, 10010',
#        'Washington Heights, New York, 10040',
#        'Financial District, New York, 10038',
#        'Gravesend, New York, 11223', 'Travis - Chelsea, New York, 10314',
#        'Long Island City, New York, 11101',
#        'Battery Park City, New York, 10280',
#        'Central Harlem, New York, 10039', 'New York, New York, 10005',
#        'Battery Park City, New York, 10282',
#        'Financial District, New York, 10006',
#        'Financial District, New York, 10005', 'Inwood, New York, 10034',
#        'East Village, New York, 10003'], dtype=object)

# %%
# left merge dataset (Integration)
NY_walkscore = pd.merge(dt_county_, walkscore, how='left', left_on='STATE', right_on='Neighborhood')
print(f"Missing Values: ")
NY_walkscore.isna().sum()
rows_with_na = NY_walkscore[NY_walkscore.isna().any(axis=1)]
# Out:
# Missing Values:
# BROKERTITLE         0
# TYPE                0
# PRICE               0
# BEDS                0
# BATH                0
# PROPERTYSQFT        0
# MAIN_ADDRESS        0
# STATE               0
# State_City          0
# LATITUDE            0
# LONGITUDE           0
# beds_has_decimal    0
# bath_has_decimal    0
# Location            0
# Bike Score          0
# Transit Score       6
# Walk Score          0
# Neighborhood        0
# dtype: int64

# %%
NY_walkscore.shape
# Out:
# (1182, 18)

# %%
NY_walkscore.head(3)
# Out:
#                                    BROKERTITLE            TYPE      PRICE  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale     315000
# 1                          Brokered by Serhant  Condo for sale  195000000
# 2                          Brokered by COMPASS  Condo for sale      69000
#
#    BEDS  BATH  PROPERTYSQFT  \
# 0     2   2.0        1400.0
# 1     7  10.0       17545.0
# 2     3   1.0         445.0
#
#                                         MAIN_ADDRESS                STATE  \
# 0             2 E 55th St Unit 803New York, NY 10022   New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...   New York, NY 10019
# 2         2 E 55th St Unit 908W33Manhattan, NY 10022  Manhattan, NY 10022
#
#   State_City   LATITUDE  LONGITUDE  beds_has_decimal bath_has_decimal  \
# 0   New York  40.761255 -73.974483             False            False
# 1   New York  40.766393 -73.980991             False            False
# 2  Manhattan  40.761398 -73.974613             False            False
#
#                           Location  Bike Score  Transit Score  Walk Score  \
# 0    Midtown East, New York, 10022          82          100.0         100
# 1  Hell's Kitchen, New York, 10019          91          100.0          93
# 2    Midtown East, New York, 10022          82          100.0         100
#
#           Neighborhood
# 0   New York, NY 10022
# 1   New York, NY 10019
# 2  Manhattan, NY 10022

# %%
# Data extracted from OSM
# public transport
public_trans = pd.read_csv("C:/Users/1999i/Documents/data mange/Lab Lectures/Project/new_york_amenities-public_transport.csv")

# hospitals
hospitals = pd.read_csv("C:/Users/1999i/Documents/data mange/Lab Lectures/Project/new_york_amenities-hospitals.csv")

# schools
schools = pd.read_csv("C:/Users/1999i/Documents/data mange/Lab Lectures/Project/new_york_amenities-schools.csv")

# %%
# Convert to geo-dataframes
# NY_walkscore
NY_gdf = gpd.GeoDataFrame(NY_walkscore, crs='EPSG:4326',
    geometry=gpd.points_from_xy(NY_walkscore.LONGITUDE, NY_walkscore.LATITUDE))

# public transport
trans_gdf = gpd.GeoDataFrame(public_trans,crs='EPSG:4326',
    geometry=gpd.points_from_xy(public_trans.lon, public_trans.lat))

# hospitals
hospitals_gdf = gpd.GeoDataFrame(hospitals,crs='EPSG:4326',
    geometry=gpd.points_from_xy(hospitals.lon, hospitals.lat))

# schools
schools_gdf = gpd.GeoDataFrame(schools,crs='EPSG:4326',
    geometry=gpd.points_from_xy(schools.lon, schools.lat))

# %%
from shapely.ops import nearest_points


def calculate_nearest(points, key_locations):
    distances = []
  
    key_union = key_locations.geometry.union_all()
    for point in points.geometry:
        nearest_geom = nearest_points(point, key_union)[1]
        distance = point.distance(nearest_geom)
        distances.append(distance)
    return distances

#  calculation for the nearest distance to schools, hospitals, and transportation hubs
NY_gdf['distance_to_school'] = calculate_nearest(NY_gdf, schools_gdf)
NY_gdf['distance_to_hospital'] = calculate_nearest(NY_gdf, hospitals_gdf)
NY_gdf['distance_to_transportation'] = calculate_nearest(NY_gdf, trans_gdf)


NY_gdf.head(3)
# Out:
#                                    BROKERTITLE            TYPE      PRICE  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale     315000
# 1                          Brokered by Serhant  Condo for sale  195000000
# 2                          Brokered by COMPASS  Condo for sale      69000
#
#    BEDS  BATH  PROPERTYSQFT  \
# 0     2   2.0        1400.0
# 1     7  10.0       17545.0
# 2     3   1.0         445.0
#
#                                         MAIN_ADDRESS                STATE  \
# 0             2 E 55th St Unit 803New York, NY 10022   New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...   New York, NY 10019
# 2         2 E 55th St Unit 908W33Manhattan, NY 10022  Manhattan, NY 10022
#
#   State_City   LATITUDE  ...  bath_has_decimal  \
# 0   New York  40.761255  ...             False
# 1   New York  40.766393  ...             False
# 2  Manhattan  40.761398  ...             False
#
#                           Location Bike Score Transit Score  Walk Score  \
# 0    Midtown East, New York, 10022         82         100.0         100
# 1  Hell's Kitchen, New York, 10019         91         100.0          93
# 2    Midtown East, New York, 10022         82         100.0         100
#
#           Neighborhood                    geometry distance_to_school  \
# 0   New York, NY 10022  POINT (-73.97448 40.76126)           0.001492
# 1   New York, NY 10019  POINT (-73.98099 40.76639)           0.003276
# 2  Manhattan, NY 10022   POINT (-73.97461 40.7614)           0.001587
#
#   distance_to_hospital  distance_to_transportation
# 0             0.011238                    0.000699
# 1             0.012035                    0.000855
# 2             0.011326                    0.000520
#
# [3 rows x 22 columns]

# %%
# converting degrees of longitude and latitude into meters
def degrees_to_meters(degrees, latitude, is_longitude=False):
    # Constants
    meters_per_degree_latitude = 111320

    if is_longitude:
        meters_per_degree_longitude = meters_per_degree_latitude * np.cos(np.radians(latitude))
        return degrees * meters_per_degree_longitude
    else:
        return degrees * meters_per_degree_latitude

# Convert distances
NY_gdf['dist_school_meters'] = degrees_to_meters(NY_gdf['distance_to_school'], NY_gdf['LATITUDE'], is_longitude=True)
NY_gdf['dist_hospital_meters'] = degrees_to_meters(NY_gdf['distance_to_hospital'] , NY_gdf['LATITUDE'], is_longitude=True)
NY_gdf['dist_transportation_meters'] = degrees_to_meters(NY_gdf['distance_to_transportation'] , NY_gdf['LATITUDE'], is_longitude=True)

NY_gdf.head(4)
# Out:
#                                      BROKERTITLE            TYPE      PRICE  \
# 0    Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale     315000
# 1                            Brokered by Serhant  Condo for sale  195000000
# 2                            Brokered by COMPASS  Condo for sale      69000
# 3  Brokered by Douglas Elliman - 575 Madison Ave  Condo for sale     899500
#
#    BEDS  BATH  PROPERTYSQFT  \
# 0     2   2.0   1400.000000
# 1     7  10.0  17545.000000
# 2     3   1.0    445.000000
# 3     2   2.0   2184.207862
#
#                                         MAIN_ADDRESS                STATE  \
# 0             2 E 55th St Unit 803New York, NY 10022   New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...   New York, NY 10019
# 2         2 E 55th St Unit 908W33Manhattan, NY 10022  Manhattan, NY 10022
# 3           157 W 126th St Unit 1BNew York, NY 10027   New York, NY 10027
#
#   State_City   LATITUDE  ...  Transit Score  Walk Score         Neighborhood  \
# 0   New York  40.761255  ...          100.0         100   New York, NY 10022
# 1   New York  40.766393  ...          100.0          93   New York, NY 10019
# 2  Manhattan  40.761398  ...          100.0         100  Manhattan, NY 10022
# 3   New York  40.809448  ...          100.0          93   New York, NY 10027
#
#                      geometry  distance_to_school  distance_to_hospital  \
# 0  POINT (-73.97448 40.76126)            0.001492              0.011238
# 1  POINT (-73.98099 40.76639)            0.003276              0.012035
# 2   POINT (-73.97461 40.7614)            0.001587              0.011326
# 3  POINT (-73.94678 40.80945)            0.001109              0.013684
#
#    distance_to_transportation dist_school_meters dist_hospital_meters  \
# 0                    0.000699         125.837685           947.576865
# 1                    0.000855         276.243418          1014.645953
# 2                    0.000520         133.850000           955.012851
# 3                    0.002021          93.421984          1152.987304
#
#    dist_transportation_meters
# 0                   58.954601
# 1                   72.079494
# 2                   43.838720
# 3                  170.252965
#
# [4 rows x 25 columns]

# %%
# spliting the location obtain by the website
NY_gdf[['Loc_Neighborhood', 'Loc_City', 'Loc_ZIP']] = NY_gdf['Location'].str.split(', ', expand=True)
NY_gdf.head(3)
# Out:
#                                    BROKERTITLE            TYPE      PRICE  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale     315000
# 1                          Brokered by Serhant  Condo for sale  195000000
# 2                          Brokered by COMPASS  Condo for sale      69000
#
#    BEDS  BATH  PROPERTYSQFT  \
# 0     2   2.0        1400.0
# 1     7  10.0       17545.0
# 2     3   1.0         445.0
#
#                                         MAIN_ADDRESS                STATE  \
# 0             2 E 55th St Unit 803New York, NY 10022   New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...   New York, NY 10019
# 2         2 E 55th St Unit 908W33Manhattan, NY 10022  Manhattan, NY 10022
#
#   State_City   LATITUDE  ...                    geometry  distance_to_school  \
# 0   New York  40.761255  ...  POINT (-73.97448 40.76126)            0.001492
# 1   New York  40.766393  ...  POINT (-73.98099 40.76639)            0.003276
# 2  Manhattan  40.761398  ...   POINT (-73.97461 40.7614)            0.001587
#
#   distance_to_hospital distance_to_transportation  dist_school_meters  \
# 0             0.011238                   0.000699          125.837685
# 1             0.012035                   0.000855          276.243418
# 2             0.011326                   0.000520          133.850000
#
#    dist_hospital_meters  dist_transportation_meters Loc_Neighborhood  \
# 0            947.576865                   58.954601     Midtown East
# 1           1014.645953                   72.079494   Hell's Kitchen
# 2            955.012851                   43.838720     Midtown East
#
#    Loc_City  Loc_ZIP
# 0  New York    10022
# 1  New York    10019
# 2  New York    10022
#
# [3 rows x 28 columns]

# %%
NY_gdf.isna().sum()
# Out:
# BROKERTITLE                   0
# TYPE                          0
# PRICE                         0
# BEDS                          0
# BATH                          0
# PROPERTYSQFT                  0
# MAIN_ADDRESS                  0
# STATE                         0
# State_City                    0
# LATITUDE                      0
# LONGITUDE                     0
# beds_has_decimal              0
# bath_has_decimal              0
# Location                      0
# Bike Score                    0
# Transit Score                 6
# Walk Score                    0
# Neighborhood                  0
# geometry                      0
# distance_to_school            0
# distance_to_hospital          0
# distance_to_transportation    0
# dist_school_meters            0
# dist_hospital_meters          0
# dist_transportation_meters    0
# Loc_Neighborhood              0
# Loc_City                      0
# Loc_ZIP                       7
# dtype: int64

# %%
NY_gdf.shape
# Out:
# (1182, 28)

# %%
DATASET = NY_gdf[['BROKERTITLE','TYPE','STATE','State_City','Neighborhood','Location', 'Loc_Neighborhood','Loc_City','Loc_ZIP',
                  'LATITUDE','LONGITUDE','geometry','PRICE','BEDS','BATH','PROPERTYSQFT','Walk Score',
                  'Transit Score','Bike Score','dist_transportation_meters','dist_hospital_meters','distance_to_school']]

# %%
DATASET.head()
# Out:
#                                      BROKERTITLE            TYPE  \
# 0    Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale
# 1                            Brokered by Serhant  Condo for sale
# 2                            Brokered by COMPASS  Condo for sale
# 3  Brokered by Douglas Elliman - 575 Madison Ave  Condo for sale
# 4          Brokered by Corcoran Chelsea/Flatiron  Co-op for sale
#
#                  STATE State_City         Neighborhood  \
# 0   New York, NY 10022   New York   New York, NY 10022
# 1   New York, NY 10019   New York   New York, NY 10019
# 2  Manhattan, NY 10022  Manhattan  Manhattan, NY 10022
# 3   New York, NY 10027   New York   New York, NY 10027
# 4   New York, NY 10014   New York   New York, NY 10014
#
#                           Location Loc_Neighborhood  Loc_City Loc_ZIP  \
# 0    Midtown East, New York, 10022     Midtown East  New York   10022
# 1  Hell's Kitchen, New York, 10019   Hell's Kitchen  New York   10019
# 2    Midtown East, New York, 10022     Midtown East  New York   10022
# 3       Manhattan, New York, 10027        Manhattan  New York   10027
# 4    West Village, New York, 10014     West Village  New York   10014
#
#     LATITUDE  ...      PRICE BEDS  BATH  PROPERTYSQFT  Walk Score  \
# 0  40.761255  ...     315000    2   2.0   1400.000000         100
# 1  40.766393  ...  195000000    7  10.0  17545.000000          93
# 2  40.761398  ...      69000    3   1.0    445.000000         100
# 3  40.809448  ...     899500    2   2.0   2184.207862          93
# 4  40.738298  ...     895000    3   1.0   2184.207862          98
#
#    Transit Score  Bike Score  dist_transportation_meters  \
# 0          100.0          82                   58.954601
# 1          100.0          91                   72.079494
# 2          100.0          82                   43.838720
# 3          100.0          60                  170.252965
# 4          100.0          94                   54.583331
#
#    dist_hospital_meters  distance_to_school
# 0            947.576865            0.001492
# 1           1014.645953            0.003276
# 2            955.012851            0.001587
# 3           1152.987304            0.001109
# 4            428.760776            0.004152
#
# [5 rows x 22 columns]

# %%
# convert to csv and save
file_path = r'C:/Users/1999i/Documents/data mange/Lab Lectures/Project/Data/DATASET_NY_COUNTY.csv'
DATASET.to_csv(file_path, index=False)
